# %%
import sys
sys.path.insert(0, '..')  # Add parent directory for imports
from dotenv import load_dotenv
from model_config import ModelConfig
import os

load_dotenv()  # loads .env file into environment variables
# Out:
# /Users/roypsr/projects/gen_ai_mind/.venv/lib/python3.14/site-packages/langchain_core/utils/pydantic.py:42: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1
# True

# %%
# Initialize the OpenRouter model using ModelConfig
llm = ModelConfig.openrouter("laguna-xs")  # Uses ROUTER_KEY and openrouter API base

# Or use explicit model ID:
# llm = ModelConfig.openrouter("nvidia/nemotron-3-ultra-550b-a55b:free")

# Test the connection
response = llm.invoke("Write a quick python function to reverse a string.")
print(response.content)
# Out:
# To reverse a string in Python efficiently, you can utilize slicing with a step of `-1`, which iterates over the string in reverse order. Here's the concise function:
#
# ```python
# def reverse_string(s):
#     return s[::-1]
# ```
#
# **Explanation:**
# - The slicing operation `s[::-1]` creates a new string by stepping backward through the original string `s`, effectively reversing it.
# - This method is both Pythonic and optimal, with a time complexity of O(n), where n is the length of the string.

# %%
llm_zen = ModelConfig.zen("laguna-s")  # Uses ROUTER_KEY and openrouter API base

# Or use explicit model ID:
# llm = ModelConfig.openrouter("nvidia/nemotron-3-ultra-550b-a55b:free")

# Test the connection
response = llm_zen.invoke("Write a quick python function to reverse a string.")
print(response.content)
# Out:
# Here's a concise Python function to reverse a string using slicing:
#
# ```python
# def reverse_string(s):
#     return s[::-1]
# ```
#
# ### How it works:
# - The slice `[::-1]` creates a reversed copy of the string.
#   - Start at the end of the string and move backwards with a step of `-1`.
#
# ### Alternative (using `reversed()`):
# ```python
# def reverse_string(s):
#     return ''.join(reversed(s))
# ```
#
# Both methods are efficient and produce the same result. The slicing approach is more Pythonic and concise. Let me know if you'd like further clarification!
