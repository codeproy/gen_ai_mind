# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
import os

load_dotenv()  # loads .env file into environment variables

api_key = os.getenv("ZEN_API_KEY")
# Out:
# /Users/roypsr/projects/gen_ai_mind/.venv/lib/python3.14/site-packages/langchain_core/utils/pydantic.py:41: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1

# %%
# Initialize the OpenCode Zen model
llm = ChatOpenAI(
    model="big-pickle", # Replace with your chosen Zen model id
    openai_api_key=api_key,
    openai_api_base="https://opencode.ai/zen/v1"
)

# Test the connection
response = llm.invoke("Write a quick python function to reverse a string.")
print(response.content)
# Out:
# Here's a simple Python function to reverse a string:
#
# ```python
# def reverse_string(s):
#     """Return the reversed version of the input string."""
#     return s[::-1]
# ```
#
# **How it works:**
# - `s[::-1]` uses Python slicing to create a reversed copy of the string.
#   The syntax is `start:stop:step`, and `step=-1` means go backwards through the string.
#
# **Example usage:**
# ```python
# print(reverse_string("hello"))   # Output: "olleh"
# print(reverse_string("Python"))  # Output: "nohtyP"
# ```
#
# This is concise and efficient—let me know if you'd like a different approach (like using a loop)!
